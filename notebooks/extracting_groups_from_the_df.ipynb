# %%
import pandas as pd

# %%
file = "../data/df.csv"
data = pd.read_csv(file)

# %%
levels = ['all', "L1-L2", "L2-L3", "L3-L4", "L4-L5", "L5-S1"]
df = data[data['Level'] == levels[]].copy()

# %%
df = pd.read_csv('../data/df.csv')

# %%
df['gt_mc_c_size_subgroup'].value_counts()
# Out:
# 0.0    5561
# 1.0    1357
# Name: gt_mc_c_size_subgroup, dtype: int64

# %%
lbp = df[df['lbp'] == 1]
size_c = df[df['gt_mc_c_size_subgroup'] == 1]
size_r = df[df['gt_mc_r_size_subgroup'] == 1]
size = [size_c, size_r]
size = pd.concat(size)
size_lbp_c = df[(df['lbp'] == 1) & (df['gt_mc_c_size_subgroup'] == 1)]
size_lbp_r = df[(df['lbp'] == 1) & (df['gt_mc_r_size_subgroup'] == 1)]
size_lbp = [size_lbp_c, size_lbp_r]
size_lbp = pd.concat(size_lbp)

groups = [lbp, size, size_c, size_r, size_lbp, size_lbp_c, size_lbp_r]

for i in groups:
    print(len(i))
# Out:
# 1665
# 2380
# 1357
# 1023
# 686
# 373
# 313

# %%
size_lbp
# Out:
#       Unnamed: 0  Unnamed: 0.1  Level  Pfirrmann  Pfirrmann_probability  \
# 12            12             2  L3-L4          3               0.785057
# 13            13             3  L4-L5          5               0.992305
# 14            14             4  L5-S1          5               0.961743
# 75            80             1  L1-L2          3               0.842814
# 77            82             3  L3-L4          4               0.724836
# ...          ...           ...    ...        ...                    ...
# 6862        7387             4  L5-S1          3               0.785929
# 6888        7413             1  L1-L2          2               0.561136
# 6924        7449             4  L2-L3          5               0.666351
# 6926        7451             6  L4-L5          4               0.835423
# 6927        7452             7  L5-S1          5               0.963104
#
#       Pfirrmann_probability_1  Pfirrmann_probability_2  \
# ...
